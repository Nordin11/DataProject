# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import io

# %%
## FINANCIAL INDUSTRY

# Call the stocks I want to analyze
financeTickers = ['JPM','BAC','WFC','V','C']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(financeTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet
close = close.dropna(axis=0, how='any')

# Define the table as a matrix
close = np.asmatrix(close)

# Print the FINANCE correlation matrix 
print np.corrcoef(close, rowvar=False)
# Out:
# [[ 1.          0.81762411  0.5360019   0.34711931  0.37814524]
#  [ 0.81762411  1.          0.06699282 -0.0593884  -0.00259447]
#  [ 0.5360019   0.06699282  1.          0.93764729  0.87880015]
#  [ 0.34711931 -0.0593884   0.93764729  1.          0.91178347]
#  [ 0.37814524 -0.00259447  0.87880015  0.91178347  1.        ]]

# %%
## TECH INDUSTRY

# Call the stocks I want to analyze
techTickers = ['GOOGL','MSFT','FB','T','VZ']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(techTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet 
close = close.dropna(axis=0, how='any')

# Define the table as a matrix
close = np.asmatrix(close)

# Print the TECH correlation matrix
print np.corrcoef(close, rowvar=False)
# Out:
# [[ 1.          0.97606687  0.97614519  0.45324442  0.28575139]
#  [ 0.97606687  1.          0.96912033  0.45803498  0.31496301]
#  [ 0.97614519  0.96912033  1.          0.45731985  0.28751156]
#  [ 0.45324442  0.45803498  0.45731985  1.          0.57584617]
#  [ 0.28575139  0.31496301  0.28751156  0.57584617  1.        ]]

# %%
## SERVICES

# Call the stocks I want to analyze
servicesTickers = ['AMZN','BABA','WMT','HD','CMCSA']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(servicesTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet 
close = close.dropna(axis=0, how='any')

# Define the table as a matrix
close = np.asmatrix(close)

# Print the SERVICES correlation matrix
print np.corrcoef(close, rowvar=False)
# Out:
# [[ 1.          0.70287888  0.89262942  0.95048717  0.14832415]
#  [ 0.70287888  1.          0.72022178  0.71114062  0.66332237]
#  [ 0.89262942  0.72022178  1.          0.86734233  0.25847002]
#  [ 0.95048717  0.71114062  0.86734233  1.          0.24237633]
#  [ 0.14832415  0.66332237  0.25847002  0.24237633  1.        ]]

# %%
## BASIC MATERIALS

# Call the stocks I want to analyze
basicTickers = ['XOM','RDS-B','PTR','CVX','BP']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(basicTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet 
close = close.dropna(axis=0, how='any')

# Define the table as a matrix
close = np.asmatrix(close)

# Print the MATERIALS correlation matrix
print np.corrcoef(close, rowvar=False)
# Out:
# [[ 1.         -0.28240457  0.2409885   0.46111994 -0.10275468]
#  [-0.28240457  1.          0.6963437   0.6210914   0.94904232]
#  [ 0.2409885   0.6963437   1.          0.75391586  0.79412953]
#  [ 0.46111994  0.6210914   0.75391586  1.          0.67479176]
#  [-0.10275468  0.94904232  0.79412953  0.67479176  1.        ]]

# %%
## CONSUMER GOODS

# Call the stocks I want to analyze
consumerTickers = ['AAPL','PG','BUD','KO','TM']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(consumerTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet 
close = close.dropna(axis=0, how='any')

# Define the table as a matrix
close = np.asmatrix(close)

# Print the GOODS correlation matrix
print np.corrcoef(close, rowvar=False)
# Out:
# [[ 1.          0.85073395  0.86739672  0.84005446  0.6920721 ]
#  [ 0.85073395  1.          0.92636245  0.90913085  0.86179124]
#  [ 0.86739672  0.92636245  1.          0.89440036  0.74545251]
#  [ 0.84005446  0.90913085  0.89440036  1.          0.82718561]
#  [ 0.6920721   0.86179124  0.74545251  0.82718561  1.        ]]

# %%
## ALL INDUSTRIES

# Call the stocks I want to analyze
financeTickers = ['JPM','BAC','WFC','V','C']
techTickers = ['GOOGL','MSFT','FB','T','VZ']
servicesTickers = ['AMZN','BABA','WMT','HD','CMCSA']
basicTickers = ['XOM','RDS-B','PTR','CVX','BP']
consumerTickers = ['AAPL','PG','BUD','KO','TM']


# group all tickers together
AllTickers = ['JPM','BAC','WFC','V','C','GOOGL','MSFT','FB','T','VZ','AMZN','BABA','WMT','HD','CMCSA','XOM','RDS-B','PTR','CVX','BP','AAPL','PG','BUD','KO','TM']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(AllTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet 
close = close.dropna(axis=0, how='any')

# Define the table as a matrix
close = np.matrix(close)

# Define and print the correlation matrix in absolute values
close = np.corrcoef(close, rowvar=False)
a = np.zeros(len(AllTickers))
for i in range(len(AllTickers)):    
    a[i] = np.sum(abs(close[i]))
        
print a - 1

# %%
## ALL INDUSTRIES

# Call the stocks I want to analyze
financeTickers = ['JPM','BAC','WFC','V','C']
techTickers = ['GOOGL','MSFT','FB','T','VZ']
servicesTickers = ['AMZN','BABA','WMT','HD','CMCSA']
basicTickers = ['XOM','RDS-B','PTR','CVX','BP']
consumerTickers = ['AAPL','PG','BUD','KO','TM']

# group all tickers together
AllTickers = ['JPM','BAC','WFC','V','C','GOOGL','MSFT','FB','T','VZ','AMZN','BABA','WMT','HD','CMCSA','XOM','RDS-B','PTR','CVX','BP','AAPL','PG','BUD','KO','TM']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(AllTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet 
close = close.dropna(axis=0, how='any')

# Define the table as a matrix
close = np.matrix(close)

# Print the correlation matrix
c = np.corrcoef(close, rowvar=False)

# manipulate the data so that I can output the proper format for the network
nodes = []

# define the different industries by seperating it in different groups 
for i in range(len(AllTickers)):
    if i < len(financeTickers):
    
        nodes.append({"id":AllTickers[i], "group": 1})
    
    elif i < len(financeTickers) + len(techTickers):
        
        nodes.append({"id":AllTickers[i], "group": 2})
        
    elif i < len(financeTickers) + len(techTickers) + len(servicesTickers):
        
        nodes.append({"id":AllTickers[i], "group": 3})
        
    elif i < len(financeTickers) + len(techTickers) + len(servicesTickers) + len(basicTickers):
        
        nodes.append({"id":AllTickers[i], "group": 4})
        
    else:
        
        nodes.append({"id":AllTickers[i], "group": 5})
        
links = []

# Go through the stocks and link the stocks and connections with eachother to the correlation matrix. 
for i in range(len(AllTickers)):
    for j in range(1,len(AllTickers) - i):
        links.append({"source" : AllTickers[i],"target" : AllTickers[i + j],"value" : c[i,i+j]})


# bring together the two dictionaries into one big dict
json_data = {
    "nodes": nodes,
    "links": links
}

network = json.dumps(json_data)

# copied this print into a downloaded json file. 
print network
# Out:
# {"nodes": [{"group": 1, "id": "JPM"}, {"group": 1, "id": "BAC"}, {"group": 1, "id": "WFC"}, {"group": 1, "id": "V"}, {"group": 1, "id": "C"}, {"group": 2, "id": "GOOGL"}, {"group": 2, "id": "MSFT"}, {"group": 2, "id": "FB"}, {"group": 2, "id": "T"}, {"group": 2, "id": "VZ"}, {"group": 3, "id": "AMZN"}, {"group": 3, "id": "BABA"}, {"group": 3, "id": "WMT"}, {"group": 3, "id": "HD"}, {"group": 3, "id": "CMCSA"}, {"group": 4, "id": "XOM"}, {"group": 4, "id": "RDS-B"}, {"group": 4, "id": "PTR"}, {"group": 4, "id": "CVX"}, {"group": 4, "id": "BP"}, {"group": 5, "id": "AAPL"}, {"group": 5, "id": "PG"}, {"group": 5, "id": "BUD"}, {"group": 5, "id": "KO"}, {"group": 5, "id": "TM"}], "links": [{"source": "JPM", "target": "BAC", "value": 0.6548940365618403}, {"source": "JPM", "target": "WFC", "value": 0.856570143726574}, {"source": "JPM", "target": "V", "value": 0.8768651736597215}, {"source": "JPM", "target": "C", "value": 0.3436835894105242}, {"source": "JPM", "target": "GOOGL", "value": -0.1241589906270564}, {"source": "JPM", "target": "MSFT", "value": 0.9074615955514475}, {"source": "JPM", "target": "FB", "value": 0.7539116828365054}, {"source": "JPM", "target": "T", "value": 0.4692885342966659}, {"source": "JPM", "target": "VZ", "value": 0.7101372834652695}, {"source": "JPM", "target": "AMZN", "value": 0.6500718328395907}, {"source": "JPM", "target": "BABA", "value": 0.713353285256368}, {"source": "JPM", "target": "WMT", "value": 0.8563042451079913}, {"source": "JPM", "target": "HD", "value": 0.3476138500439475}, {"source": "JPM", "target": "CMCSA", "value": 0.7676004461511768}, {"source": "JPM", "target": "XOM", "value": 0.5099165364141619}, {"source": "JPM", "target": "RDS-B", "value": -0.15775567518982234}, {"source": "JPM", "target": "PTR", "value": 0.2850659063816065}, {"source": "JPM", "target": "CVX", "value": 0.006863037392116159}, {"source": "JPM", "target": "BP", "value": 0.17646439834714858}, {"source": "JPM", "target": "AAPL", "value": 0.7870668073005447}, {"source": "JPM", "target": "PG", "value": -0.28417145217316736}, {"source": "JPM", "target": "BUD", "value": 0.5457300169196172}, {"source": "JPM", "target": "KO", "value": 0.5818007785521457}, {"source": "JPM", "target": "TM", "value": -0.33696039294599794}, {"source": "BAC", "target": "WFC", "value": 0.7028788814583103}, {"source": "BAC", "target": "V", "value": 0.7353019067753426}, {"source": "BAC", "target": "C", "value": -0.23332244393036328}, {"source": "BAC", "target": "GOOGL", "value": -0.06075588965269614}, {"source": "BAC", "target": "MSFT", "value": 0.6066507388618294}, {"source": "BAC", "target": "FB", "value": 0.8926294201160433}, {"source": "BAC", "target": "T", "value": 0.28604461251979196}, {"source": "BAC", "target": "VZ", "value": 0.9739784352779446}, {"source": "BAC", "target": "AMZN", "value": 0.9768461596043166}, {"source": "BAC", "target": "BABA", "value": 0.9504871719803678}, {"source": "BAC", "target": "WMT", "value": 0.85578447369395}, {"source": "BAC", "target": "HD", "value": 0.5772189233316506}, {"source": "BAC", "target": "CMCSA", "value": 0.9366906532858125}, {"source": "BAC", "target": "XOM", "value": 0.4496138577952692}, {"source": "BAC", "target": "RDS-B", "value": -0.768822605597484}, {"source": "BAC", "target": "PTR", "value": -0.2552513240469852}, {"source": "BAC", "target": "CVX", "value": 0.5311560243085635}, {"source": "BAC", "target": "BP", "value": -0.4168017620262247}, {"source": "BAC", "target": "AAPL", "value": 0.9498973405258637}, {"source": "BAC", "target": "PG", "value": 0.02701984453237047}, {"source": "BAC", "target": "BUD", "value": 0.060753232359459224}, {"source": "BAC", "target": "KO", "value": 0.14832414720834022}, {"source": "BAC", "target": "TM", "value": -0.35722145253608795}, {"source": "WFC", "target": "V", "value": 0.834023104085674}, {"source": "WFC", "target": "C", "value": 0.30222902052912154}, {"source": "WFC", "target": "GOOGL", "value": -0.09923159257678855}, {"source": "WFC", "target": "MSFT", "value" ...

# %%
## ALL INDUSTRIES

# Call the stocks I want to analyze
financeTickers = ['JPM','BAC','WFC','V','C']
techTickers = ['GOOGL','MSFT','FB','T','VZ']
servicesTickers = ['AMZN','BABA','WMT','HD','CMCSA']
basicTickers = ['XOM','RDS-B','PTR','CVX','BP']
consumerTickers = ['AAPL','PG','BUD','KO','TM']

# group all tickers together
AllTickers = ['JPM','BAC','WFC','V','C','GOOGL','MSFT','FB','T','VZ','AMZN','BABA','WMT','HD','CMCSA','XOM','RDS-B','PTR','CVX','BP','AAPL','PG','BUD','KO','TM']

# Define the data source
data_source = 'yahoo'

# Define the time-scale
start_date = '2000-01-01'
end_date = '2018-01-01'

# Get the data
panel_data = data.DataReader(AllTickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Drop the dates where one of the companies wasn't public yet 
close = close.dropna(axis=0, how='any')

# normalize de data by defining relative gain. starting at the first price 1.0 
close = close/close.iloc[0, :]

close.to_csv('price_relative_gain.csv',  encoding='utf-8')
